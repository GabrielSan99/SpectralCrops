# %%
import pandas as pd
import os

# %%
spectral_dict = {
    'UVA': 365,
    'Violet': 405,
    'Indigo': 430,
    'Blue_1': 450,
    'Blue_2': 470,
    'Azure': 490,
    'Cyan': 515,
    'Green': 540,
    'Yellow': 570,
    'Amber': 590,
    'Red_1': 630,
    'Red_2': 645,
    'Red_3'
}

# %% [markdown]
# # Luz Acesa

# %%
PATH = "C:/Users/gabri/OneDrive/Documentos/Projeto Mestrado"

df = pd.read_csv("C:/Users/gabri/OneDrive/Documentos/Projeto Mestrado/VideoMeter_Spectros_Aceso/capture00000.txt", sep='\t')
df
# Out:
#        344,25  1267,69
# 0      344,46  1267,69
# 1      344,68  1267,69
# 2      344,90  1247,21
# 3      345,12  1261,55
# 4      345,34  1404,91
# ...       ...      ...
# 3642  1042,27  1462,25
# 3643  1042,43  1429,48
# 3644  1042,59  1468,39
# 3645  1042,75  1400,81
# 3646  1042,91  1443,82
#
# [3647 rows x 2 columns]
